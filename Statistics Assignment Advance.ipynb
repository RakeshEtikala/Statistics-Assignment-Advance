# %% [markdown]
# Q1. What is the Probability density function ?

# %% [markdown]
# 1. Its shows basically about continuous data.
#
#  If our data is in continuous random variable and if we want to check distribution of that data we use probability density function.
#
# e.g.: -  Height of students, Weight of people, But never it will be zero

# %% [markdown]
# Q2. What are the types of Probability distribution?
#
# Ans : - 1. Normal / Gaussian Distribution (pdf) - Most of the data follows normal or gaussian distribution
#
# 2. Bernoulli distribution - Classification Problem (pmf) Only two outcomes {Success or Failure}
#
# 3. Uniform Distribution
#
# 4. Log Normal distribution - (pdf)
#
# 5. Poisson distribution - (pmf)
#
# 6. Power Law distribution - (pdf) - 80-20% Rule
#
# 7. Binomial Distribution (pmf)

# %% [markdown]
# Q4. What are the properties of Binomial distribution? Give two examples of events where binomial
# distribution can be applied

# %% [markdown]
# The outcomes of this are binary and we are repeating it for n number of times for those kind of distribution we need binomial distribution.
#
# n =  number of times
#
# p = discrete probability distribution
#
# success with probability  = p
#
# failure with probability q= 1-p
#
# E.g. : - Tossing a coin {Bernoulli Distribution}
#
# E.g. : - Tossing a coin for 10 times (Binomial distribution)

# %% [markdown]
# Q5. Generate a random sample of size 1000 from a binomial distribution with probability of success 0.4
# and plot a histogram of the results using matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
probability_of_success = 0.4
sample_size = 1000
random_sample = np.random.binomial(1, probability_of_success, sample_size)
plt.hist(random_sample, bins=[-0.5, 0.5, 1.5], edgecolor='black')
plt.title('Binomial Distribution with p=0.4')
plt.xlabel('Outcome')
plt.ylabel('Frequency')
plt.xticks([0, 1], ['Failure (0)', 'Success (1)'])
plt.show()

# %% [markdown]
# Q6. Generate a random sample of size 1000 from a Poisson distribution with mean 5 and calculate the
# sample mean and variance.

# %%
import numpy as np
import matplotlib.pyplot as plt
mean = 5
sample_size = 1000
random_sample = np.random.poisson(probability_of_success, mean)
plt.hist(random_sample, bins=[-0.5, 0.5, 1.5], edgecolor='black')
plt.title('Mean with 5')
plt.xlabel('Outcome')
plt.ylabel('Frequency')
plt.xticks([0, 1], ['Failure (0)', 'Success (1)'])
plt.show()

# %% [markdown]
# Q7. How Binomial distribution different from Poisson distribution

# %% [markdown]
# It describes the number of events occurring in fixed time interval is called poisson distribution.
#
# The outcomes of this are binary and we are repeating it for n number of times for those kind of distribution we need binomial distribution.

# %% [markdown]
# Q8. How mean and variance are related in Binomial distribution and Poisson distribution

# %% [markdown]
# 10. In normal distribution with respect to mean position, where does the least frequent data appear?

# %% [markdown]
# In a normal distribution, the least frequent data appears in the tails, located at the extremes on either side of the mean.
